# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
labels=['Dog','Cat','Horse']

# %%
np.random.seed(1)

# %%
W=np.random.randn(3,3072)
b=np.random.randn(3)

# %%
test_image=cv2.imread(r"dog.4.jpg")

# %%
img=cv2.resize(test_image,(32,32)).flatten()

# %%
scores=np.dot(W,img)+b

# %%
for (label,score)in zip(labels,scores):
    print(f"INFO {label}:{score}")
# Out:
# INFO Dog:11515.807233578618
# INFO Cat:-376.06728355893887
# INFO Horse:-1693.981454850154

# %%
cv2.putText(test_image,f"Label : {labels[np.argmax(scores)]}",(10,30),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,0),2)
test_image=cv2.cvtColor(test_image,cv2.COLOR_BGR2RGB)
plt.imshow(test_image)
plt.axis("off")
# Out:
# (-0.5, 299.5, 286.5, -0.5)

# %%
print(img.shape)
# Out:
# (3072,)

# %%
for i in range()
# Out:
#   File "<ipython-input-11-f8d1be0104ca>", line 1
#     for i in range()
#                     ^
# SyntaxError: invalid syntax

# %%
ts=[1,2]

# %%
cv2.resize(ts,(2,1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6348acb20053> in <module>
# ----> 1 cv2.resize(ts,(2,1))
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'

# %%
x
